# %%
import pandas as pd

# %%
df=pd.read_csv('Student Mental health (updated).csv')

# %%
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  08-07-20 12:02             Female  18.0          Engineering
# 1  08-07-20 12:04               Male  21.0    Islamic education
# 2  08-07-20 12:05               Male  19.0                  BIT
# 3  08-07-20 12:06             Female  22.0                 Laws
# 4  08-07-20 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? CGPA Category Marital status  \
# 0                     year 1        3.00 - 3.49       Average             No
# 1                     year 2        3.00 - 3.49       Average             No
# 2                     Year 1        3.00 - 3.49       Average             No
# 3                     year 3        3.00 - 3.49       Average            Yes
# 4                     year 4        3.00 - 3.49       Average             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# ...

# %%
pd.crosstab(df['Timestamp'],df['Choose your gender'])
# Out:
# Choose your gender  Female  Male
# Timestamp
# 08-07-20 12:02           1     0
# 08-07-20 12:04           0     1
# 08-07-20 12:05           0     1
# 08-07-20 12:06           1     0
# 08-07-20 12:13           0     1
# ...                    ...   ...
# 13-07-20 19:56           1     0
# 13-07-20 21:21           0     1
# 13-07-20 21:22           1     0
# 13-07-20 21:23           1     0
# 18-07-20 20:16           0     1
#
# [90 rows x 2 columns]

# %%
pd.crosstab(df['Timestamp'],df['Age'])
# Out:
# Age             18.0  19.0  20.0  21.0  22.0  23.0  24.0
# Timestamp
# 08-07-20 12:02     1     0     0     0     0     0     0
# 08-07-20 12:04     0     0     0     1     0     0     0
# 08-07-20 12:05     0     1     0     0     0     0     0
# 08-07-20 12:06     0     0     0     0     1     0     0
# 08-07-20 12:13     0     0     0     0     0     1     0
# ...              ...   ...   ...   ...   ...   ...   ...
# 13-07-20 19:56     0     0     0     1     0     0     0
# 13-07-20 21:21     1     0     0     0     0     0     0
# 13-07-20 21:22     0     1     0     0     0     0     0
# 13-07-20 21:23     0     0     0     0     0     1     0
# 18-07-20 20:16     0     0     1     0     0     0     0
#
# [89 rows x 7 columns]

# %%
pd.crosstab(df['Timestamp'],df['What is your course?'])
# Out:
# What is your course?  ALA  Accounting   BCS  BENL  BIT  Banking Studies  Benl  \
# Timestamp
# 08-07-20 12:02          0            0    0     0    0                0     0
# 08-07-20 12:04          0            0    0     0    0                0     0
# 08-07-20 12:05          0            0    0     0    1                0     0
# 08-07-20 12:06          0            0    0     0    0                0     0
# 08-07-20 12:13          0            0    0     0    0                0     0
# ...                   ...          ...  ...   ...  ...              ...   ...
# 13-07-20 19:56          0            0    1     0    0                0     0
# 13-07-20 21:21          0            0    0     0    0                0     0
# 13-07-20 21:22          0            0    0     0    0                0     0
# 13-07-20 21:23          0            0    0     0    0                0     0
# 18-07-20 20:16          0            0    0     0    0                0     0
#
# ...

# %%
pd.crosstab(df['Timestamp'],df['Your current year of Study'])
# Out:
# Your current year of Study  Year 1  Year 2  Year 3  year 1  year 2  year 3  \
# Timestamp
# 08-07-20 12:02                   0       0       0       1       0       0
# 08-07-20 12:04                   0       0       0       0       1       0
# 08-07-20 12:05                   1       0       0       0       0       0
# 08-07-20 12:06                   0       0       0       0       0       1
# 08-07-20 12:13                   0       0       0       0       0       0
# ...                            ...     ...     ...     ...     ...     ...
# 13-07-20 19:56                   0       0       0       1       0       0
# 13-07-20 21:21                   0       1       0       0       0       0
# 13-07-20 21:22                   0       0       1       0       0       0
# 13-07-20 21:23                   0       0       0       0       0       0
# 18-07-20 20:16                   0       1       0       0       0       0
#
# Your current year of Study  year 4
# Timestamp
# ...

# %%
pd.crosstab(df['Timestamp'],df['What is your CGPA?'])
# Out:
# What is your CGPA?  0 - 1.99  2.00 - 2.49  2.50 - 2.99  3.00 - 3.49  \
# Timestamp
# 08-07-20 12:02             0            0            0            1
# 08-07-20 12:04             0            0            0            1
# 08-07-20 12:05             0            0            0            1
# 08-07-20 12:06             0            0            0            1
# 08-07-20 12:13             0            0            0            1
# ...                      ...          ...          ...          ...
# 13-07-20 19:56             0            0            0            0
# 13-07-20 21:21             0            0            0            1
# 13-07-20 21:22             0            0            0            0
# 13-07-20 21:23             0            0            0            0
# 18-07-20 20:16             0            0            0            1
#
# What is your CGPA?  3.50 - 4.00  3.50 - 4.00
# Timestamp
# 08-07-20 12:02                0             0
# ...

# %%
pd.crosstab(df['Timestamp'],df['CGPA Category'])
# Out:
# CGPA Category   Average  Bad  Excellent  Fail
# Timestamp
# 08-07-20 12:02        1    0          0     0
# 08-07-20 12:04        1    0          0     0
# 08-07-20 12:05        1    0          0     0
# 08-07-20 12:06        1    0          0     0
# 08-07-20 12:13        1    0          0     0
# ...                 ...  ...        ...   ...
# 13-07-20 19:56        0    0          1     0
# 13-07-20 21:21        1    0          0     0
# 13-07-20 21:22        0    0          1     0
# 13-07-20 21:23        0    0          1     0
# 18-07-20 20:16        1    0          0     0
#
# [90 rows x 4 columns]

# %%
pd.crosstab(df['Timestamp'],df['Marital status'])
# Out:
# Marital status  No  Yes
# Timestamp
# 08-07-20 12:02   1    0
# 08-07-20 12:04   1    0
# 08-07-20 12:05   1    0
# 08-07-20 12:06   0    1
# 08-07-20 12:13   1    0
# ...             ..  ...
# 13-07-20 19:56   1    0
# 13-07-20 21:21   1    0
# 13-07-20 21:22   0    1
# 13-07-20 21:23   1    0
# 18-07-20 20:16   1    0
#
# [90 rows x 2 columns]

# %%
pd.crosstab(df['Timestamp'],df['Do you have Depression?'])
# Out:
# Do you have Depression?  No  Yes
# Timestamp
# 08-07-20 12:02            0    1
# 08-07-20 12:04            1    0
# 08-07-20 12:05            0    1
# 08-07-20 12:06            0    1
# 08-07-20 12:13            1    0
# ...                      ..  ...
# 13-07-20 19:56            1    0
# 13-07-20 21:21            0    1
# 13-07-20 21:22            0    1
# 13-07-20 21:23            1    0
# 18-07-20 20:16            1    0
#
# [90 rows x 2 columns]

# %%
pd.crosstab(df['Timestamp'],df['Do you have Anxiety?'])
# Out:
# Do you have Anxiety?  No  Yes
# Timestamp
# 08-07-20 12:02         1    0
# 08-07-20 12:04         0    1
# 08-07-20 12:05         0    1
# 08-07-20 12:06         1    0
# 08-07-20 12:13         1    0
# ...                   ..  ...
# 13-07-20 19:56         0    1
# 13-07-20 21:21         0    1
# 13-07-20 21:22         1    0
# 13-07-20 21:23         1    0
# 18-07-20 20:16         1    0
#
# [90 rows x 2 columns]

# %%
pd.crosstab(df['Timestamp'],df['Do you have Panic attack?'])
# Out:
# Do you have Panic attack?  No  Yes
# Timestamp
# 08-07-20 12:02              0    1
# 08-07-20 12:04              1    0
# 08-07-20 12:05              0    1
# 08-07-20 12:06              1    0
# 08-07-20 12:13              1    0
# ...                        ..  ...
# 13-07-20 19:56              1    0
# 13-07-20 21:21              1    0
# 13-07-20 21:22              0    1
# 13-07-20 21:23              1    0
# 18-07-20 20:16              1    0
#
# [90 rows x 2 columns]

# %%
pd.crosstab(df['Timestamp'],df['Did you seek any specialist for a treatment?'])
# Out:
# Did you seek any specialist for a treatment?  No  Yes
# Timestamp
# 08-07-20 12:02                                 1    0
# 08-07-20 12:04                                 1    0
# 08-07-20 12:05                                 1    0
# 08-07-20 12:06                                 1    0
# 08-07-20 12:13                                 1    0
# ...                                           ..  ...
# 13-07-20 19:56                                 1    0
# 13-07-20 21:21                                 1    0
# 13-07-20 21:22                                 1    0
# 13-07-20 21:23                                 1    0
# 18-07-20 20:16                                 1    0
#
# [90 rows x 2 columns]

# %%
pd.crosstab(df['Choose your gender'],df['Age'])
# Out:
# Age                 18.0  19.0  20.0  21.0  22.0  23.0  24.0
# Choose your gender
# Female                24    16     5     1     2     9    18
# Male                   8     5     1     2     0     4     5

# %%
pd.crosstab(df['Choose your gender'],df['What is your course?'])
# Out:
# What is your course?  ALA  Accounting   BCS  BENL  BIT  Banking Studies  Benl  \
# Choose your gender
# Female                  1            1   11     2    6                1     1
# Male                    0            0    7     0    4                0     0
#
# What is your course?  Biomedical science  Biotechnology  \
# Choose your gender
# Female                                 2              1
# Male                                   2              0
#
# What is your course?  Business Administration  ...  Pendidikan Islam  \
# Choose your gender                             ...
# Female                                      1  ...                 1
# Male                                        0  ...                 0
#
# What is your course?  Pendidikan Islam   Pendidikan islam  Psychology  \
# Choose your gender
# Female                                1                 1           1
# Male                                  0                 0           0
#
# ...

# %%
pd.crosstab(df['Choose your gender'],df['Your current year of Study'])
# Out:
# Your current year of Study  Year 1  Year 2  Year 3  year 1  year 2  year 3  \
# Choose your gender
# Female                           1       9      15      32       6       5
# Male                             1       7       4       9       4       0
#
# Your current year of Study  year 4
# Choose your gender
# Female                           7
# Male                             1

# %%
pd.crosstab(df['Choose your gender'],df['What is your CGPA?'])
# Out:
# What is your CGPA?  0 - 1.99  2.00 - 2.49  2.50 - 2.99  3.00 - 3.49  \
# Choose your gender
# Female                     2            1            4           29
# Male                       2            1            0           14
#
# What is your CGPA?  3.50 - 4.00  3.50 - 4.00
# Choose your gender
# Female                       38             1
# Male                          9             0

# %%
pd.crosstab(df['Choose your gender'],df['CGPA Category'])
# Out:
# CGPA Category       Average  Bad  Excellent  Fail
# Choose your gender
# Female                   29    4         39     3
# Male                     14    0          9     3

# %%
pd.crosstab(df['Choose your gender'],df['Marital status'])
# Out:
# Marital status      No  Yes
# Choose your gender
# Female              62   13
# Male                23    3

# %%
pd.crosstab(df['Choose your gender'],df['Do you have Depression?'])
# Out:
# Do you have Depression?  No  Yes
# Choose your gender
# Female                   46   29
# Male                     20    6

# %%
pd.crosstab(df['Choose your gender'],df['Do you have Anxiety?'])
# Out:
# Do you have Anxiety?  No  Yes
# Choose your gender
# Female                51   24
# Male                  16   10

# %%
pd.crosstab(df['Choose your gender'],df['Do you have Panic attack?'])
# Out:
# Do you have Panic attack?  No  Yes
# Choose your gender
# Female                     50   25
# Male                       18    8

# %%
pd.crosstab(df['Choose your gender'],df['Did you seek any specialist for a treatment?'])
# Out:
# Did you seek any specialist for a treatment?  No  Yes
# Choose your gender
# Female                                        70    5
# Male                                          25    1
